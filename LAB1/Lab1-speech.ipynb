# %% [markdown]
# ## A1. Load the recorded speech file into your python workspace. Once loaded, plot the graph for thespeech signal.

# %%
import librosa

y, sr = librosa.load('speeech.wav')
librosa.display.waveshow(y)

# %% [markdown]
# ## A2. Observe the length & magnitude range of the signal from the plot. Observing the plot, relate tothe spoken words and silence between the words.

# %%
import numpy as np

# %%
print("Length of the signal:",len(y))
print("Magnitude range:",np.min(y),"to", np.max(y))
# Out:
# Length of the signal: 47485
# Magnitude range: -0.6024071 to 0.5690077

# %% [markdown]
# ## A3. Take a small segment of the signal and play it.

# %%
import sounddevice as sd

# %%
start_time = 1
end_time = 1.25
start_sample = int(start_time * sr)
end_sample = int(end_time * sr)
segment = y[start_sample:end_sample]

librosa.display.waveshow(segment)

sd.play(segment, sr)
sd.wait()

# %% [markdown]
# ## A4. Play around with your recorded speech signal for various segments. Understand the nature ofthe signal. Also observe with abruptly segmented speech, how the perception of that speech isaffected.

# %%
from IPython.display import Audio

# %%
start =0.6
end= 1.2
segment = y[int(start* sr):int(end* sr)]
Audio(segment, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveshow(segment)

# %%
start1 =1.4
end1= 1.6
segment1 = y[int(start1* sr):int(end1* sr)]
Audio(segment1, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveshow(segment1)
